# %%
import pandas as pd

# %%
#loading the csvss file in here
df=pd.read_csv(r"C:\Users\user\Desktop\pandas\pokemon_data.csv")

# %%
df
# Out:
#        #                   Name    Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur     Grass  Poison  45      49       49
# 1      2                Ivysaur     Grass  Poison  60      62       63
# 2      3               Venusaur     Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur     Grass  Poison  80     100      123
# 4      4             Charmander      Fire     NaN  39      52       43
# ..   ...                    ...       ...     ...  ..     ...      ...
# 104   96                Drowzee   Psychic     NaN  60      48       45
# 105   97                  Hypno   Psychic     NaN  85      73       70
# 106   98                 Krabby     Water     NaN  30     105       90
# 107   99                Kingler     Water     NaN  55     130      115
# 108  100                Voltorb  Electric     NaN  40      30       50
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
#reading the data 
#FIRST OF ALLL
#read headers
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#read each column
print(df["Name"])
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 104                  Drowzee
# 105                    Hypno
# 106                   Krabby
# 107                  Kingler
# 108                  Voltorb
# Name: Name, Length: 109, dtype: object

# %%
#read each row 
print(df.head(5)) #with head also can use df.iloc()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#read a specific location 
print(df.iloc[3,4])
# Out:
# 80

# %%
#to iterate through each row
for index, row in df.iterrows():
    print(index,row)
# Out:
# 0 #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object
# 1 #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object
# 2 #                    3
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# Name: 2, dtype: object
# ...

# %%
#using loc to get based on some condition 
df.loc[df['Type 1']=="Fire"]
# Out:
#      #                       Name Type 1  Type 2  HP  Attack  Defense  \
# 4    4                 Charmander   Fire     NaN  39      52       43
# 5    5                 Charmeleon   Fire     NaN  58      64       58
# 6    6                  Charizard   Fire  Flying  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying  78     104       78
# 42  37                     Vulpix   Fire     NaN  38      41       40
# 43  38                  Ninetales   Fire     NaN  73      76       75
# 63  58                  Growlithe   Fire     NaN  55      70       45
# 64  59                   Arcanine   Fire     NaN  90     110       80
# 83  77                     Ponyta   Fire     NaN  50      85       55
# 84  78                   Rapidash   Fire     NaN  65     100       70
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4        60       50     65           1      False
# ...

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  109.000000  109.000000  109.000000  109.000000  109.000000  109.000000
# mean    49.045872   60.752294   71.376147   66.064220   68.917431   64.412844
# std     29.864318   21.323416   25.431385   29.890936   34.034059   23.995837
# min      1.000000   10.000000   20.000000   15.000000   15.000000   20.000000
# 25%     22.000000   45.000000   50.000000   45.000000   45.000000   45.000000
# 50%     49.000000   60.000000   70.000000   60.000000   65.000000   65.000000
# 75%     75.000000   78.000000   85.000000   80.000000   85.000000   80.000000
# max    100.000000  140.000000  150.000000  180.000000  175.000000  120.000000
#
#             Speed  Generation
# count  109.000000       109.0
# mean    69.743119         1.0
# std     28.345881         0.0
# min     15.000000         1.0
# 25%     45.000000         1.0
# 50%     70.000000         1.0
# 75%     90.000000         1.0
# ...

# %%
#SORTING N DESCRIBING DATA
df.sort_values('Name')
# Out:
#      #                   Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 68  63                   Abra  Psychic     NaN   25      20       15      105
# 70  65               Alakazam  Psychic     NaN   55      50       45      135
# 71  65  AlakazamMega Alakazam  Psychic     NaN   55      50       65      175
# 29  24                  Arbok   Poison     NaN   60      85       69       65
# 64  59               Arcanine     Fire     NaN   90     110       80      100
# ..  ..                    ...      ...     ...  ...     ...      ...      ...
# 10   8              Wartortle    Water     NaN   59      63       80       65
# 16  13                 Weedle      Bug  Poison   40      35       30       20
# 76  70             Weepinbell    Grass  Poison   65      90       50       85
# 45  40             Wigglytuff   Normal   Fairy  140      70       45       85
# 46  41                  Zubat   Poison  Flying   40      45       35       30
#
# ...

# %%
#more specificly
df.sort_values(["Type 1","HP"])
# Out:
#      #                 Name Type 1    Type 2  HP  Attack  Defense  Sp. Atk  \
# 51  46                Paras    Bug     Grass  35      70       55       45
# 16  13               Weedle    Bug    Poison  40      35       30       20
# 13  10             Caterpie    Bug       NaN  45      30       35       20
# 17  14               Kakuna    Bug    Poison  45      25       50       25
# 14  11              Metapod    Bug       NaN  50      20       55       25
# ..  ..                  ...    ...       ...  ..     ...      ...      ...
# 67  62            Poliwrath  Water  Fighting  90      95       95       70
# 85  79             Slowpoke  Water   Psychic  90      65       65       40
# 94  87              Dewgong  Water       Ice  90      70       80       70
# 86  80              Slowbro  Water   Psychic  95      75      110      100
# 87  80  SlowbroMega Slowbro  Water   Psychic  95      75      180      130
#
#     Sp. Def  Speed  Generation  Legendary
# ...

# %%
#MAKING CHANGES TO DATA 
#If i want a one column with all these stats ..to get which pokemon is more powerful we gonna do
df["total"]=df["HP"]+df["Sp. Def"]+df["Sp. Atk"]+df["Speed"] +df["Defense"]
df
# Out:
#        #                   Name    Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur     Grass  Poison  45      49       49
# 1      2                Ivysaur     Grass  Poison  60      62       63
# 2      3               Venusaur     Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur     Grass  Poison  80     100      123
# 4      4             Charmander      Fire     NaN  39      52       43
# ..   ...                    ...       ...     ...  ..     ...      ...
# 104   96                Drowzee   Psychic     NaN  60      48       45
# 105   97                  Hypno   Psychic     NaN  85      73       70
# 106   98                 Krabby     Water     NaN  30     105       90
# 107   99                Kingler     Water     NaN  55     130      115
# 108  100                Voltorb  Electric     NaN  40      30       50
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  total
# ...

# %%
#if you wanna delete some columns 
df=df.drop(columns=['total','HP','Generation'])
df
# Out:
#        #                   Name    Type 1  Type 2  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur     Grass  Poison      49       49       65
# 1      2                Ivysaur     Grass  Poison      62       63       80
# 2      3               Venusaur     Grass  Poison      82       83      100
# 3      3  VenusaurMega Venusaur     Grass  Poison     100      123      122
# 4      4             Charmander      Fire     NaN      52       43       60
# ..   ...                    ...       ...     ...     ...      ...      ...
# 104   96                Drowzee   Psychic     NaN      48       45       43
# 105   97                  Hypno   Psychic     NaN      73       70       73
# 106   98                 Krabby     Water     NaN     105       90       25
# 107   99                Kingler     Water     NaN     130      115       50
# 108  100                Voltorb  Electric     NaN      30       50       55
#
#      Sp. Def  Speed  Legendary
# ...

# %%
#Another way to do total
df["total"]=df.iloc[:,4:10].sum(axis=1)
df
# Out:
#        #                   Name    Type 1  Type 2  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur     Grass  Poison      49       49       65
# 1      2                Ivysaur     Grass  Poison      62       63       80
# 2      3               Venusaur     Grass  Poison      82       83      100
# 3      3  VenusaurMega Venusaur     Grass  Poison     100      123      122
# 4      4             Charmander      Fire     NaN      52       43       60
# ..   ...                    ...       ...     ...     ...      ...      ...
# 104   96                Drowzee   Psychic     NaN      48       45       43
# 105   97                  Hypno   Psychic     NaN      73       70       73
# 106   98                 Krabby     Water     NaN     105       90       25
# 107   99                Kingler     Water     NaN     130      115       50
# 108  100                Voltorb  Electric     NaN      30       50       55
#
#      Sp. Def  Speed  Legendary  total
# ...

# %%
#to chnage position of columns 
cols=list(df.columns.values)
df= df[cols[0:3]+[cols[-1]]+cols[3:10]]
df
# Out:
#        #                   Name    Type 1  total  Type 2  Attack  Defense  \
# 0      1              Bulbasaur     Grass  273.0  Poison      49       49
# 1      2                Ivysaur     Grass  345.0  Poison      62       63
# 2      3               Venusaur     Grass  445.0  Poison      82       83
# 3      3  VenusaurMega Venusaur     Grass  545.0  Poison     100      123
# 4      4             Charmander      Fire  270.0     NaN      52       43
# ..   ...                    ...       ...    ...     ...     ...      ...
# 104   96                Drowzee   Psychic  268.0     NaN      48       45
# 105   97                  Hypno   Psychic  398.0     NaN      73       70
# 106   98                 Krabby     Water  295.0     NaN     105       90
# 107   99                Kingler     Water  420.0     NaN     130      115
# 108  100                Voltorb  Electric  290.0     NaN      30       50
#
#      Sp. Atk  Sp. Def  Speed  Legendary
# ...

# %%
df
# Out:
#        #                   Name    Type 1  total  Type 2  Attack  Defense  \
# 0      1              Bulbasaur     Grass  273.0  Poison      49       49
# 1      2                Ivysaur     Grass  345.0  Poison      62       63
# 2      3               Venusaur     Grass  445.0  Poison      82       83
# 3      3  VenusaurMega Venusaur     Grass  545.0  Poison     100      123
# 4      4             Charmander      Fire  270.0     NaN      52       43
# ..   ...                    ...       ...    ...     ...     ...      ...
# 104   96                Drowzee   Psychic  268.0     NaN      48       45
# 105   97                  Hypno   Psychic  398.0     NaN      73       70
# 106   98                 Krabby     Water  295.0     NaN     105       90
# 107   99                Kingler     Water  420.0     NaN     130      115
# 108  100                Voltorb  Electric  290.0     NaN      30       50
#
#      Sp. Atk  Sp. Def  Speed  Legendary
# ...

# %%
#FILTERING DATA
df.loc[df["Type 1"]=="Grass"]
# Out:
#      #                   Name Type 1  total  Type 2  Attack  Defense  Sp. Atk  \
# 0    1              Bulbasaur  Grass  273.0  Poison      49       49       65
# 1    2                Ivysaur  Grass  345.0  Poison      62       63       80
# 2    3               Venusaur  Grass  445.0  Poison      82       83      100
# 3    3  VenusaurMega Venusaur  Grass  545.0  Poison     100      123      122
# 48  43                 Oddish  Grass  275.0  Poison      50       55       75
# 49  44                  Gloom  Grass  335.0  Poison      65       70       85
# 50  45              Vileplume  Grass  415.0  Poison      80       85      110
# 75  69             Bellsprout  Grass  250.0  Poison      75       35       70
# 76  70             Weepinbell  Grass  325.0  Poison      90       50       85
# 77  71             Victreebel  Grass  410.0  Poison     105       65      100
#
#     Sp. Def  Speed  Legendary
# 0        65     45      False
# 1        80     60      False
# ...

# %%
#GIVING MULTIPLE FILTERS
df.loc[(df["Type 1"]=="Grass") & (df["Type 2"]=="Poison")]  # can also do "OR"
# Out:
#      #                   Name Type 1  total  Type 2  Attack  Defense  Sp. Atk  \
# 0    1              Bulbasaur  Grass  273.0  Poison      49       49       65
# 1    2                Ivysaur  Grass  345.0  Poison      62       63       80
# 2    3               Venusaur  Grass  445.0  Poison      82       83      100
# 3    3  VenusaurMega Venusaur  Grass  545.0  Poison     100      123      122
# 48  43                 Oddish  Grass  275.0  Poison      50       55       75
# 49  44                  Gloom  Grass  335.0  Poison      65       70       85
# 50  45              Vileplume  Grass  415.0  Poison      80       85      110
# 75  69             Bellsprout  Grass  250.0  Poison      75       35       70
# 76  70             Weepinbell  Grass  325.0  Poison      90       50       85
# 77  71             Victreebel  Grass  410.0  Poison     105       65      100
#
#     Sp. Def  Speed  Legendary
# 0        65     45      False
# 1        80     60      False
# ...

# %%
#if i want all pokemon with total greater than 300
df.loc[(df["total"]>=300)]
# Out:
#       #                   Name   Type 1  total  Type 2  Attack  Defense  \
# 1     2                Ivysaur    Grass  345.0  Poison      62       63
# 2     3               Venusaur    Grass  445.0  Poison      82       83
# 3     3  VenusaurMega Venusaur    Grass  545.0  Poison     100      123
# 5     5             Charmeleon     Fire  347.0     NaN      64       58
# 6     6              Charizard     Fire  456.0  Flying      84       78
# ..   ..                    ...      ...    ...     ...     ...      ...
# 101  94                 Gengar    Ghost  440.0  Poison      65       60
# 102  94      GengarMega Gengar    Ghost  540.0  Poison      65       80
# 103  95                   Onix     Rock  350.0  Ground      45      160
# 105  97                  Hypno  Psychic  398.0     NaN      73       70
# 107  99                Kingler    Water  420.0     NaN     130      115
#
#      Sp. Atk  Sp. Def  Speed  Legendary
# 1         80       80     60      False
# ...

# %%
#some more conditions
df.loc[(df["Type 1"]=="Grass") & (df["Type 2"]=="Poison") & (df["Defense"]>80)]
# Out:
#      #                   Name Type 1  total  Type 2  Attack  Defense  Sp. Atk  \
# 2    3               Venusaur  Grass  445.0  Poison      82       83      100
# 3    3  VenusaurMega Venusaur  Grass  545.0  Poison     100      123      122
# 50  45              Vileplume  Grass  415.0  Poison      80       85      110
#
#     Sp. Def  Speed  Legendary
# 2       100     80      False
# 3       120     80      False
# 50       90     50      False

# %%
#FILTERATION BASED ON TEXTUAL PATTRENS
df.loc[df["Name"].str.contains('saur')]
# Out:
#    #                   Name Type 1  total  Type 2  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  273.0  Poison      49       49       65
# 1  2                Ivysaur  Grass  345.0  Poison      62       63       80
# 2  3               Venusaur  Grass  445.0  Poison      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  545.0  Poison     100      123      122
#
#    Sp. Def  Speed  Legendary
# 0       65     45      False
# 1       80     60      False
# 2      100     80      False
# 3      120     80      False

# %%
#CONDITIONAL CHANGES
#I want flamer instaed of fire in type 1
df.loc[df["Type 1"]=="Fire","Type 1"]="Flamer"
df
# Out:
#        #                   Name    Type 1  total  Type 2  Attack  Defense  \
# 0      1              Bulbasaur     Grass  273.0  Poison      49       49
# 1      2                Ivysaur     Grass  345.0  Poison      62       63
# 2      3               Venusaur     Grass  445.0  Poison      82       83
# 3      3  VenusaurMega Venusaur     Grass  545.0  Poison     100      123
# 4      4             Charmander    Flamer  270.0     NaN      52       43
# ..   ...                    ...       ...    ...     ...     ...      ...
# 104   96                Drowzee   Psychic  268.0     NaN      48       45
# 105   97                  Hypno   Psychic  398.0     NaN      73       70
# 106   98                 Krabby     Water  295.0     NaN     105       90
# 107   99                Kingler     Water  420.0     NaN     130      115
# 108  100                Voltorb  Electric  290.0     NaN      30       50
#
#      Sp. Atk  Sp. Def  Speed  Legendary
# ...

# %%
df.loc[df["total"]>300,"Legendary"]="GOOD"
df
# Out:
#        #                   Name    Type 1  total  Type 2  Attack  Defense  \
# 0      1              Bulbasaur     Grass  273.0  Poison      49       49
# 1      2                Ivysaur     Grass  345.0  Poison      62       63
# 2      3               Venusaur     Grass  445.0  Poison      82       83
# 3      3  VenusaurMega Venusaur     Grass  545.0  Poison     100      123
# 4      4             Charmander    Flamer  270.0     NaN      52       43
# ..   ...                    ...       ...    ...     ...     ...      ...
# 104   96                Drowzee   Psychic  268.0     NaN      48       45
# 105   97                  Hypno   Psychic  398.0     NaN      73       70
# 106   98                 Krabby     Water  295.0     NaN     105       90
# 107   99                Kingler     Water  420.0     NaN     130      115
# 108  100                Voltorb  Electric  290.0     NaN      30       50
#
#      Sp. Atk  Sp. Def  Speed Legendary
# 0         65       65     45     False
# ...

# %%
#AGGREGATE STATISTICS (GROUP BY)
df.groupby(["Type 1"]).mean()
# Out:
#                   #       total     Attack     Defense     Sp. Atk    Sp. Def  \
# Type 1
# Bug       25.454545  266.818182  61.818182   49.545455   43.181818  54.090909
# Electric  62.800000  343.000000  54.000000   62.000000   82.000000  62.000000
# Fairy     35.500000  320.500000  57.500000   60.500000   77.500000  77.500000
# Fighting  62.800000  326.000000  99.000000   59.000000   49.000000  59.000000
# Flamer    34.000000  403.000000  83.272727   66.636364   89.454545  76.363636
# Ghost     93.250000  405.000000  53.750000   53.750000  128.750000  65.000000
# Grass     35.100000  361.800000  75.800000   67.800000   89.200000  74.000000
# Ground    39.000000  312.500000  77.500000   67.500000   37.500000  50.000000
# Normal    39.133333  307.933333  69.466667   51.333333   56.333333  51.266667
# Poison    41.333333  311.750000  73.916667   60.250000   54.583333  62.333333
# Psychic   75.000000  381.833333  46.000000   45.000000  108.500000  86.666667
# ...

# %%
#if i want to count
df.groupby(["Type 1"]).count()
# Out:
#            #  Name  total  Type 2  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug       11    11     11       9      11       11       11       11     11
# Electric   5     5      5       2       5        5        5        5      5
# Fairy      2     2      2       0       2        2        2        2      2
# Fighting   5     5      5       0       5        5        5        5      5
# Flamer    11    11     11       3      11       11       11       11     11
# Ghost      4     4      4       4       4        4        4        4      4
# Grass     10    10     10      10      10       10       10       10     10
# Ground     4     4      4       0       4        4        4        4      4
# Normal    15    15     15      11      15       15       15       15     15
# Poison    12    12     12       4      12       12       12       12     12
# Psychic    6     6      6       0       6        6        6        6      6
# ...

# %%
#WRITING DATFRAME BACK INTO CSV 
df.to_csv("newmodified.csv")

# %%
#WE CAN LOAD EXCEL FILE ALSO
df=pd.read_excel("weatherdata.xlsx")

# %%
df
# Out:
#             Unnamed: 0   Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0                  Day  TEMPERATURE  WINDSPEED      EVENT
# 1  2017-01-01 00:00:00           32          6       Rain
# 2  2017-04-01 00:00:00          NaN          9      Sunny
# 3  2017-05-01 00:00:00           28        NaN       Snow
# 4  2017-06-01 00:00:00          NaN          7        NaN
# 5  2017-07-01 00:00:00           32         32       Rain
# 6  2017-08-01 00:00:00          NaN        NaN      Sunny
# 7  2017-09-01 00:00:00          NaN        NaN        NaN
# 8  2017-10-01 00:00:00           34          8     Cloudy
# 9  2017-11-01 00:00:00           40         12      Sunny

# %%
#to write back in excel use to_excel
